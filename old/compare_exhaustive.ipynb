# %%
from contextlib import contextmanager
from itertools import permutations
from math import factorial
from pathlib import Path

import os
import sys
import time
import timeit

import numpy as np
import pandas as pd
import xmltodict

import logging

from score_strokes import alignStrokes
from xmlparse import loadGeometryBases, loadRef, getXmlScore, minXml

# %%
# Edited from exhaustive.py
def computeExhaustive(ref_char, f_read, data_dir, exhaust_dir = "Exhaustive", prog_interval = 100, save = True, xml_dir = "GenXml/Exhaustive", save_file = ""):
    ref_g, ref_l, output_size = loadRef(ref_char, ref_dir)
    g_data, _, base_data, stroke_sets, _, f_names = loadGeometryBases(data_dir, output_size, f_read = f_read)
    n_strokes = len(ref_g)
    for i in range(len(g_data)):
        #print(f"Generating exhaustive scores for sample {f_read[i]}")
        bases = base_data[i]
        stroke_set = stroke_sets[i]
        exhaustive_alignments = permutations(range(1, n_strokes+1))
        exhaustive_scores = np.zeros(factorial(n_strokes))
        for j, p in enumerate(exhaustive_alignments):
            p_xml = minXml(ref_char, bases, stroke_set, p)
            exhaustive_scores[j] = getXmlScore(p_xml, f"{xml_dir}/{i}_{j}_{f_read[i]}", f"{xml_dir}/{i}_{j}_min_{f_read[i]}")
            #exhaustive_scores[j] = getXmlScore(p_xml, False, False)
            #if j%prog_interval == 0:
            #    print(f"Scoring permutation {j} of {len(exhaustive_scores)}")
        if save:
            if save_file == "":
                f_name_cleaned = f_read[i].replace("/", "_")
                f"{exhaust_dir}/exhaust_{ref_char}_{f_name_cleaned}.npy"
            print(f"Wrote exhaustive scores to {save_file}")
            np.save(save_file, exhaustive_scores)
        yield exhaustive_scores

# %% [markdown]
# ## Exhaustive Comparison Function

# %%
"""
Function to compare a heuristic algorithm's accuracy and performance against the exhaustive search.
"""
def compareExhaustive(algo, ref_data, char_data, trials):
    ref_geometry, ref_progress_percentage, output_size = ref_data
    g_data, han_chars, base_data, stroke_sets, _, f_names = char_data
    
    
    def heuristic(algo):
        heuristic_scores = []
        heuristic_alignments = []
        for (geometry_length, bases, stroke_set, f_name) in zip(g_data, base_data, stroke_sets, f_names):
            geometry, progress_percentage = geometry_length
            heuristic_alignment = np.array(algo(geometry, ref_geometry, progress_percentage, ref_progress_percentage))+1
            heuristic_alignments.append(heuristic_alignment)
            heuristic_xml = minXml(ref_char, bases, stroke_set, heuristic_alignment)
            heuristic_score = getXmlScore(heuristic_xml)
            heuristic_scores.append(heuristic_score)
        return heuristic_scores, heuristic_alignments

    def exhaustive():
        exhaustive_scores = []
        for (gl, han_char, bases, f_name) in zip(g_data, han_chars, base_data, f_names):
            g, l = gl
            exhaust_maxes = []
            for e in computeExhaustive(ref_char, [f_name], data_dir, save = False, xml_dir = f'{str(Path.home())}/Stylus_Scoring_Generalization/GenXml/Exhaustive'):
                exhaust_maxes.append(e.max())
            original_score = np.max(exhaust_maxes)
            exhaustive_scores.append(original_score)
        return exhaustive_scores

    wins1 = 0
    wins2 = 0
    scores1, _ = heuristic(algo)
    scores2 = exhaustive()

    for (score1, score2) in zip(scores1, scores2):
        if score1 > score2:
            wins1 += 1
        elif score2 > score1:
            wins2 += 1

    results1 = timeit.timeit("heuristic(algo)", number=trials, globals=locals())
    results2 = timeit.timeit("exhaustive()", number=trials, globals=locals())
    time.sleep(5) # to make it easier to find results
    print("The heuristic algorithm took", results1, "seconds to execute", trials, "times.")
    print("The exhaustive search took", results2, "seconds to execute", trials, "times.")
    print("The heuristic algorithm scored", wins1, "genes more accurately than the exhaustive search.")
    print("The exhaustive search scored", wins2, "genes more accurately than the heuristic algorithm.")
    print("The heuristic algorithm and exhaustive search scored", len(scores1)-wins1-wins2, "genes identically.")

"""
Function to compare a heuristic algorithm's accuracy and performance against the exhaustive search. Uses a different method of recording benchmarks.
"""
def compareExhaustive2(algo, ref_data, char_data):
    ref_geometry, ref_progress_percentage, output_size = ref_data
    g_data, han_chars, base_data, stroke_sets, _, f_names = char_data
    
    
    def heuristic(algo):
        heuristic_scores = []
        heuristic_alignments = []
        for (geometry_length, bases, stroke_set, f_name) in zip(g_data, base_data, stroke_sets, f_names):
            geometry, progress_percentage = geometry_length
            heuristic_alignment = np.array(algo(geometry, ref_geometry, progress_percentage, ref_progress_percentage))+1
            heuristic_alignments.append(heuristic_alignment)
            heuristic_xml = minXml(ref_char, bases, stroke_set, heuristic_alignment)
            heuristic_score = getXmlScore(heuristic_xml)
            heuristic_scores.append(heuristic_score)
        return heuristic_scores, heuristic_alignments

    def exhaustive():
        exhaustive_scores = []
        for (gl, han_char, bases, f_name) in zip(g_data, han_chars, base_data, f_names):
            g, l = gl
            exhaust_maxes = []
            for e in computeExhaustive(ref_char, [f_name], data_dir, save = False, xml_dir = f'{str(Path.home())}/Stylus_Scoring_Generalization/GenXml/Exhaustive'):
                exhaust_maxes.append(e.max())
            original_score = np.max(exhaust_maxes)
            exhaustive_scores.append(original_score)
        return exhaustive_scores

    wins1 = 0
    wins2 = 0
    init1 = time.time()
    scores1, _ = heuristic(algo)
    results1 = time.time()-init1
    init2 = time.time()
    scores2 = exhaustive()
    results2 = time.time()-init2

    for (score1, score2) in zip(scores1, scores2):
        if score1 > score2:
            wins1 += 1
        elif score2 > score1:
            wins2 += 1
    
    print("The heuristic algorithm took", results1, "seconds to execute.")
    print("The exhaustive search took", results2, "seconds to execute.")
    print("The heuristic algorithm scored", wins1, "genes more accurately than the exhaustive search.")
    print("The exhaustive search scored", wins2, "genes more accurately than the heuristic algorithm.")
    print("The heuristic algorithm and exhaustive search scored", len(scores1)-wins1-wins2, "genes identically.")

# %%
ref_dir = f'{str(Path.home())}/Stylus_Scoring_Generalization/Reference' # archetype directory
data_dir = f'{str(Path.home())}/Stylus_Scoring_Generalization/NewGenes' # gene directory
ref_char = "6709"

ref_data = loadRef(ref_char, ref_dir)
char_data = loadGeometryBases(data_dir, ref_data[2])

# Still need to find a way to disable Stylus logging trial output
#stylusengine.setRecordRate(500, ["none"], "", False)
#logging.disable(logging.CRITICAL)
#compareExhaustive(alignStrokes, ref_data, char_data, 1)

compareExhaustive2(alignStrokes, ref_data, char_data)
# Out:
# 2024-06-10T22:54:45.799367Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.799458Z [INFO ] TRIAL 0: Fitness is 0.001342939948137
# 2024-06-10T22:54:45.807823Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.807878Z [INFO ] TRIAL 0: Fitness is 0.000513359096713
# 2024-06-10T22:54:45.811262Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.811309Z [INFO ] TRIAL 0: Fitness is 0.000310655915354
# 2024-06-10T22:54:45.812219Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.812258Z [INFO ] TRIAL 0: Fitness is 0.000299573812395
# 2024-06-10T22:54:45.813101Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.813140Z [INFO ] TRIAL 0: Fitness is 0.000025056729068
# 2024-06-10T22:54:45.813958Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.813996Z [INFO ] TRIAL 0: Fitness is 0.000029431767979
# 2024-06-10T22:54:45.814832Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.814885Z [INFO ] TRIAL 0: Fitness is 0.000025245826338
# 2024-06-10T22:54:45.815713Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.815750Z [INFO ] TRIAL 0: Fitness is 0.000030816047422
# 2024-06-10T22:54:45.816566Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.816601Z [INFO ] TRIAL 0: Fitness is 0.006704833359363
# 2024-06-10T22:54:45.817422Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.817458Z [INFO ] TRIAL 0: Fitness is 0.006405205570320
# 2024-06-10T22:54:45.818281Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.818319Z [INFO ] TRIAL 0: Fitness is 0.000019150758156
# 2024-06-10T22:54:45.819118Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.819155Z [INFO ] TRIAL 0: Fitness is 0.000016924194470
# 2024-06-10T22:54:45.819969Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.820014Z [INFO ] TRIAL 0: Fitness is 0.000019297870928
# 2024-06-10T22:54:45.820835Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.820871Z [INFO ] TRIAL 0: Fitness is 0.000017710577249
# 2024-06-10T22:54:45.821684Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.821720Z [INFO ] TRIAL 0: Fitness is 0.005245978638626
# 2024-06-10T22:54:45.822537Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.822573Z [INFO ] TRIAL 0: Fitness is 0.005978665284283
# 2024-06-10T22:54:45.823386Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.823422Z [INFO ] TRIAL 0: Fitness is 0.000184311650708
# 2024-06-10T22:54:45.824248Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.824284Z [INFO ] TRIAL 0: Fitness is 0.000161560953225
# 2024-06-10T22:54:45.825108Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.825143Z [INFO ] TRIAL 0: Fitness is 0.000055051975719
# 2024-06-10T22:54:45.825940Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.825976Z [INFO ] TRIAL 0: Fitness is 0.000041456377241
# 2024-06-10T22:54:45.826770Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.826804Z [INFO ] TRIAL 0: Fitness is 0.005907145467792
# 2024-06-10T22:54:45.827603Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.827637Z [INFO ] TRIAL 0: Fitness is 0.007093386694665
# 2024-06-10T22:54:45.828440Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.828475Z [INFO ] TRIAL 0: Fitness is 0.000202964652461
# 2024-06-10T22:54:45.829289Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.829324Z [INFO ] TRIAL 0: Fitness is 0.000184734219201
# 2024-06-10T22:54:45.830134Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.830170Z [INFO ] TRIAL 0: Fitness is 0.000060422385924
# 2024-06-10T22:54:45.830994Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.831030Z [INFO ] TRIAL 0: Fitness is 0.000045380024489
# 2024-06-10T22:54:45.831836Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.831872Z [INFO ] TRIAL 0: Fitness is 0.000650228251133
# 2024-06-10T22:54:45.832694Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.832729Z [INFO ] TRIAL 0: Fitness is 0.000624925887946
# 2024-06-10T22:54:45.833536Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.833572Z [INFO ] TRIAL 0: Fitness is 0.000052907285042
# 2024-06-10T22:54:45.834375Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.834410Z [INFO ] TRIAL 0: Fitness is 0.000059786257219
# 2024-06-10T22:54:45.835220Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.835255Z [INFO ] TRIAL 0: Fitness is 0.000053332401456
# 2024-06-10T22:54:45.836059Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.836094Z [INFO ] TRIAL 0: Fitness is 0.000062762954319
# 2024-06-10T22:54:45.836881Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.836915Z [INFO ] TRIAL 0: Fitness is 0.000184771266985
# 2024-06-10T22:54:45.837706Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.837740Z [INFO ] TRIAL 0: Fitness is 0.000176112441379
# 2024-06-10T22:54:45.838528Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.838562Z [INFO ] TRIAL 0: Fitness is 0.000025855309220
# 2024-06-10T22:54:45.839346Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.839380Z [INFO ] TRIAL 0: Fitness is 0.000026181708993
# 2024-06-10T22:54:45.840175Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.840210Z [INFO ] TRIAL 0: Fitness is 0.000026091230600
# 2024-06-10T22:54:45.840998Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.841032Z [INFO ] TRIAL 0: Fitness is 0.000027614401740
# 2024-06-10T22:54:45.841817Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.841851Z [INFO ] TRIAL 0: Fitness is 0.000147606920666
# 2024-06-10T22:54:45.842636Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.842671Z [INFO ] TRIAL 0: Fitness is 0.000165050371854
# 2024-06-10T22:54:45.843451Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.843486Z [INFO ] TRIAL 0: Fitness is 0.000254796245776
# 2024-06-10T22:54:45.844305Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.844340Z [INFO ] TRIAL 0: Fitness is 0.000254964017009
# 2024-06-10T22:54:45.845139Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.845173Z [INFO ] TRIAL 0: Fitness is 0.000074591330046
# 2024-06-10T22:54:45.845957Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.845990Z [INFO ] TRIAL 0: Fitness is 0.000066179813683
# 2024-06-10T22:54:45.846772Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.846806Z [INFO ] TRIAL 0: Fitness is 0.000167327870036
# 2024-06-10T22:54:45.847585Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.847618Z [INFO ] TRIAL 0: Fitness is 0.000197594251139
# 2024-06-10T22:54:45.848406Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.848441Z [INFO ] TRIAL 0: Fitness is 0.000286732604778
# 2024-06-10T22:54:45.849221Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.849254Z [INFO ] TRIAL 0: Fitness is 0.000299819316890
# 2024-06-10T22:54:45.850025Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.850059Z [INFO ] TRIAL 0: Fitness is 0.000083336941386
# 2024-06-10T22:54:45.850841Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.850875Z [INFO ] TRIAL 0: Fitness is 0.000073590602709
# 2024-06-10T22:54:45.851652Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.851685Z [INFO ] TRIAL 0: Fitness is 0.000169135960150
# 2024-06-10T22:54:45.852477Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.852510Z [INFO ] TRIAL 0: Fitness is 0.000164217659713
# 2024-06-10T22:54:45.853299Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.853333Z [INFO ] TRIAL 0: Fitness is 0.000000346037889
# 2024-06-10T22:54:45.854120Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.854154Z [INFO ] TRIAL 0: Fitness is 0.000000291323827
# 2024-06-10T22:54:45.854939Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.854988Z [INFO ] TRIAL 0: Fitness is 0.000000347824628
# 2024-06-10T22:54:45.855752Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.855784Z [INFO ] TRIAL 0: Fitness is 0.000000300280750
# 2024-06-10T22:54:45.856570Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.856603Z [INFO ] TRIAL 0: Fitness is 0.000001503259905
# 2024-06-10T22:54:45.857374Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.857407Z [INFO ] TRIAL 0: Fitness is 0.000001461657349
# 2024-06-10T22:54:45.858175Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.858208Z [INFO ] TRIAL 0: Fitness is 0.000000206018868
# 2024-06-10T22:54:45.858972Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.859005Z [INFO ] TRIAL 0: Fitness is 0.000000219216783
# 2024-06-10T22:54:45.859774Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.859807Z [INFO ] TRIAL 0: Fitness is 0.000000207122515
# 2024-06-10T22:54:45.860591Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.860625Z [INFO ] TRIAL 0: Fitness is 0.000000226231326
# 2024-06-10T22:54:45.861390Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.861423Z [INFO ] TRIAL 0: Fitness is 0.000000879270044
# 2024-06-10T22:54:45.862190Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.862223Z [INFO ] TRIAL 0: Fitness is 0.000000753113335
# 2024-06-10T22:54:45.862993Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.863026Z [INFO ] TRIAL 0: Fitness is 0.000060117408172
# 2024-06-10T22:54:45.863798Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.863832Z [INFO ] TRIAL 0: Fitness is 0.000062332200694
# 2024-06-10T22:54:45.864624Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.864658Z [INFO ] TRIAL 0: Fitness is 0.000000303072644
# 2024-06-10T22:54:45.865435Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.865468Z [INFO ] TRIAL 0: Fitness is 0.000000382718944
# 2024-06-10T22:54:45.866233Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.866265Z [INFO ] TRIAL 0: Fitness is 0.000000947934383
# 2024-06-10T22:54:45.867024Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.867056Z [INFO ] TRIAL 0: Fitness is 0.000000835590507
# 2024-06-10T22:54:45.867816Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.867848Z [INFO ] TRIAL 0: Fitness is 0.000065354608230
# 2024-06-10T22:54:45.868656Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.868690Z [INFO ] TRIAL 0: Fitness is 0.000069948616375
# 2024-06-10T22:54:45.869448Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.869479Z [INFO ] TRIAL 0: Fitness is 0.000000323242574
# 2024-06-10T22:54:45.870243Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.870275Z [INFO ] TRIAL 0: Fitness is 0.000000408236088
# 2024-06-10T22:54:45.871029Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.871061Z [INFO ] TRIAL 0: Fitness is 0.000020030234668
# 2024-06-10T22:54:45.871816Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.871848Z [INFO ] TRIAL 0: Fitness is 0.000022615173754
# 2024-06-10T22:54:45.872616Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.872648Z [INFO ] TRIAL 0: Fitness is 0.000000499389741
# 2024-06-10T22:54:45.873402Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.873435Z [INFO ] TRIAL 0: Fitness is 0.000000418409793
# 2024-06-10T22:54:45.874209Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.874241Z [INFO ] TRIAL 0: Fitness is 0.000000005460939
# 2024-06-10T22:54:45.875016Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.875048Z [INFO ] TRIAL 0: Fitness is 0.000000003549052
# 2024-06-10T22:54:45.875803Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.875834Z [INFO ] TRIAL 0: Fitness is 0.000000186861637
# 2024-06-10T22:54:45.876596Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.876629Z [INFO ] TRIAL 0: Fitness is 0.000000213080968
# 2024-06-10T22:54:45.877395Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.877427Z [INFO ] TRIAL 0: Fitness is 0.000000306631202
# 2024-06-10T22:54:45.878175Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.878207Z [INFO ] TRIAL 0: Fitness is 0.000000320044442
# 2024-06-10T22:54:45.878966Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.878997Z [INFO ] TRIAL 0: Fitness is 0.000000004671840
# 2024-06-10T22:54:45.879750Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.879782Z [INFO ] TRIAL 0: Fitness is 0.000000003598267
# 2024-06-10T22:54:45.880542Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.880575Z [INFO ] TRIAL 0: Fitness is 0.000000134028964
# 2024-06-10T22:54:45.881316Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.881349Z [INFO ] TRIAL 0: Fitness is 0.000000115082838
# 2024-06-10T22:54:45.882101Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.882133Z [INFO ] TRIAL 0: Fitness is 0.000008942611576
# 2024-06-10T22:54:45.882886Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.882917Z [INFO ] TRIAL 0: Fitness is 0.000009231591694
# 2024-06-10T22:54:45.883671Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.883703Z [INFO ] TRIAL 0: Fitness is 0.000000001729742
# 2024-06-10T22:54:45.884474Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.884506Z [INFO ] TRIAL 0: Fitness is 0.000000002088588
# 2024-06-10T22:54:45.885280Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.885312Z [INFO ] TRIAL 0: Fitness is 0.000000139428857
# 2024-06-10T22:54:45.886065Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.886096Z [INFO ] TRIAL 0: Fitness is 0.000000104865541
# 2024-06-10T22:54:45.886853Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.886884Z [INFO ] TRIAL 0: Fitness is 0.000009370453691
# 2024-06-10T22:54:45.887639Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.887670Z [INFO ] TRIAL 0: Fitness is 0.000008496408422
# 2024-06-10T22:54:45.888429Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.888460Z [INFO ] TRIAL 0: Fitness is 0.000000159555550
# 2024-06-10T22:54:45.889208Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.889239Z [INFO ] TRIAL 0: Fitness is 0.000000198562949
# 2024-06-10T22:54:45.889989Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.890020Z [INFO ] TRIAL 0: Fitness is 0.000020417715906
# 2024-06-10T22:54:45.890765Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.890797Z [INFO ] TRIAL 0: Fitness is 0.000023817004629
# 2024-06-10T22:54:45.891540Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.891571Z [INFO ] TRIAL 0: Fitness is 0.000000507632466
# 2024-06-10T22:54:45.892329Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.892361Z [INFO ] TRIAL 0: Fitness is 0.000000436930337
# 2024-06-10T22:54:45.893118Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.893149Z [INFO ] TRIAL 0: Fitness is 0.000000005579841
# 2024-06-10T22:54:45.893894Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.893926Z [INFO ] TRIAL 0: Fitness is 0.000000003623819
# 2024-06-10T22:54:45.894683Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.894714Z [INFO ] TRIAL 0: Fitness is 0.000000190386214
# 2024-06-10T22:54:45.895468Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.895499Z [INFO ] TRIAL 0: Fitness is 0.000000224120653
# 2024-06-10T22:54:45.896254Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.896285Z [INFO ] TRIAL 0: Fitness is 0.000000311927523
# 2024-06-10T22:54:45.897036Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.897067Z [INFO ] TRIAL 0: Fitness is 0.000000334873317
# 2024-06-10T22:54:45.897816Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.897847Z [INFO ] TRIAL 0: Fitness is 0.000000004784548
# 2024-06-10T22:54:45.898591Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.898621Z [INFO ] TRIAL 0: Fitness is 0.000000003680757
# 2024-06-10T22:54:45.899374Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.899405Z [INFO ] TRIAL 0: Fitness is 0.000000136577966
# 2024-06-10T22:54:45.900148Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.900179Z [INFO ] TRIAL 0: Fitness is 0.000000120978458
# 2024-06-10T22:54:45.900921Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.900951Z [INFO ] TRIAL 0: Fitness is 0.000009129171289
# 2024-06-10T22:54:45.901703Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.901734Z [INFO ] TRIAL 0: Fitness is 0.000009749444032
# 2024-06-10T22:54:45.902498Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.902529Z [INFO ] TRIAL 0: Fitness is 0.000000001769264
# 2024-06-10T22:54:45.903283Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.903313Z [INFO ] TRIAL 0: Fitness is 0.000000002135826
# 2024-06-10T22:54:45.904121Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.904152Z [INFO ] TRIAL 0: Fitness is 0.000000130709013
# 2024-06-10T22:54:45.904903Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.904933Z [INFO ] TRIAL 0: Fitness is 0.000000098425811
# 2024-06-10T22:54:45.905694Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.905724Z [INFO ] TRIAL 0: Fitness is 0.000008729689872
# 2024-06-10T22:54:45.906479Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.906510Z [INFO ] TRIAL 0: Fitness is 0.000007929799420
# 2024-06-10T22:54:45.907264Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.907295Z [INFO ] TRIAL 0: Fitness is 0.000000150556037
# 2024-06-10T22:54:45.908039Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.908070Z [INFO ] TRIAL 0: Fitness is 0.000000187377216
# 2024-06-10T22:54:45.908805Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.908835Z [INFO ] TRIAL 0: Fitness is 0.000000029970513
# 2024-06-10T22:54:45.909573Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.909603Z [INFO ] TRIAL 0: Fitness is 0.000000029189448
# 2024-06-10T22:54:45.910334Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.910365Z [INFO ] TRIAL 0: Fitness is 0.000000001799921
# 2024-06-10T22:54:45.911096Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.911126Z [INFO ] TRIAL 0: Fitness is 0.000000002448009
# 2024-06-10T22:54:45.911856Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.911887Z [INFO ] TRIAL 0: Fitness is 0.000000001812423
# 2024-06-10T22:54:45.912626Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.912657Z [INFO ] TRIAL 0: Fitness is 0.000000002553458
# 2024-06-10T22:54:45.913391Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.913422Z [INFO ] TRIAL 0: Fitness is 0.000004161240872
# 2024-06-10T22:54:45.914155Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.914185Z [INFO ] TRIAL 0: Fitness is 0.000004035481255
# 2024-06-10T22:54:45.914929Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.914960Z [INFO ] TRIAL 0: Fitness is 0.000000001033763
# 2024-06-10T22:54:45.915693Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.915723Z [INFO ] TRIAL 0: Fitness is 0.000000000770093
# 2024-06-10T22:54:45.916474Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.916505Z [INFO ] TRIAL 0: Fitness is 0.000000001041084
# 2024-06-10T22:54:45.917234Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.917264Z [INFO ] TRIAL 0: Fitness is 0.000000000802762
# 2024-06-10T22:54:45.917993Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.918024Z [INFO ] TRIAL 0: Fitness is 0.000003039523367
# 2024-06-10T22:54:45.918749Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.918779Z [INFO ] TRIAL 0: Fitness is 0.000003890699426
# 2024-06-10T22:54:45.919505Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.919535Z [INFO ] TRIAL 0: Fitness is 0.000000012569451
# 2024-06-10T22:54:45.920274Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.920303Z [INFO ] TRIAL 0: Fitness is 0.000000009258611
# 2024-06-10T22:54:45.921039Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.921069Z [INFO ] TRIAL 0: Fitness is 0.000000003187164
# 2024-06-10T22:54:45.921800Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.921830Z [INFO ] TRIAL 0: Fitness is 0.000000001747823
# 2024-06-10T22:54:45.922564Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.922593Z [INFO ] TRIAL 0: Fitness is 0.000003295103857
# 2024-06-10T22:54:45.923323Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.923353Z [INFO ] TRIAL 0: Fitness is 0.000004365443885
# 2024-06-10T22:54:45.924091Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.924121Z [INFO ] TRIAL 0: Fitness is 0.000000013496302
# 2024-06-10T22:54:45.924852Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.924883Z [INFO ] TRIAL 0: Fitness is 0.000000010213838
# 2024-06-10T22:54:45.925625Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.925655Z [INFO ] TRIAL 0: Fitness is 0.000000003476268
# 2024-06-10T22:54:45.926380Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.926409Z [INFO ] TRIAL 0: Fitness is 0.000000001900865
# 2024-06-10T22:54:45.927135Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.927165Z [INFO ] TRIAL 0: Fitness is 0.001275217551003
# 2024-06-10T22:54:45.927892Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.927922Z [INFO ] TRIAL 0: Fitness is 0.001206896957667
# 2024-06-10T22:54:45.928656Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.928686Z [INFO ] TRIAL 0: Fitness is 0.000065334691503
# 2024-06-10T22:54:45.929417Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.929447Z [INFO ] TRIAL 0: Fitness is 0.000077291320209
# 2024-06-10T22:54:45.930171Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.930201Z [INFO ] TRIAL 0: Fitness is 0.000066087272747
# 2024-06-10T22:54:45.930929Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.930958Z [INFO ] TRIAL 0: Fitness is 0.000082964045860
# 2024-06-10T22:54:45.931687Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.931717Z [INFO ] TRIAL 0: Fitness is 0.000002595108065
# 2024-06-10T22:54:45.932446Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.932476Z [INFO ] TRIAL 0: Fitness is 0.000002466454967
# 2024-06-10T22:54:45.933322Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.933362Z [INFO ] TRIAL 0: Fitness is 0.000070609153271
# 2024-06-10T22:54:45.934165Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.934196Z [INFO ] TRIAL 0: Fitness is 0.000055948822096
# 2024-06-10T22:54:45.934922Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.934951Z [INFO ] TRIAL 0: Fitness is 0.000071917635016
# 2024-06-10T22:54:45.935693Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.935722Z [INFO ] TRIAL 0: Fitness is 0.000061689594481
# 2024-06-10T22:54:45.936450Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.936480Z [INFO ] TRIAL 0: Fitness is 0.000002009837362
# 2024-06-10T22:54:45.937206Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.937235Z [INFO ] TRIAL 0: Fitness is 0.000002433307619
# 2024-06-10T22:54:45.937957Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.937987Z [INFO ] TRIAL 0: Fitness is 0.001054972175797
# 2024-06-10T22:54:45.938699Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.938728Z [INFO ] TRIAL 0: Fitness is 0.000820114239470
# 2024-06-10T22:54:45.939448Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.939477Z [INFO ] TRIAL 0: Fitness is 0.000227719976558
# 2024-06-10T22:54:45.940211Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.940241Z [INFO ] TRIAL 0: Fitness is 0.000143011770899
# 2024-06-10T22:54:45.940966Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.940997Z [INFO ] TRIAL 0: Fitness is 0.000002296775232
# 2024-06-10T22:54:45.941721Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.941750Z [INFO ] TRIAL 0: Fitness is 0.000002953689217
# 2024-06-10T22:54:45.942474Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.942504Z [INFO ] TRIAL 0: Fitness is 0.001342939948137
# 2024-06-10T22:54:45.943223Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.943253Z [INFO ] TRIAL 0: Fitness is 0.001101060821772
# 2024-06-10T22:54:45.943987Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.944022Z [INFO ] TRIAL 0: Fitness is 0.000291088229013
# 2024-06-10T22:54:45.944747Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.944777Z [INFO ] TRIAL 0: Fitness is 0.000173711894594
# 2024-06-10T22:54:45.945504Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.945534Z [INFO ] TRIAL 0: Fitness is 0.000352598640424
# 2024-06-10T22:54:45.946257Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.946286Z [INFO ] TRIAL 0: Fitness is 0.000338264026529
# 2024-06-10T22:54:45.947009Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.947038Z [INFO ] TRIAL 0: Fitness is 0.000000759289542
# 2024-06-10T22:54:45.947757Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.947788Z [INFO ] TRIAL 0: Fitness is 0.000000652093236
# 2024-06-10T22:54:45.948524Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.948554Z [INFO ] TRIAL 0: Fitness is 0.000000765387144
# 2024-06-10T22:54:45.949282Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.949312Z [INFO ] TRIAL 0: Fitness is 0.000000683585173
# 2024-06-10T22:54:45.950038Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.950067Z [INFO ] TRIAL 0: Fitness is 0.000000013004498
# 2024-06-10T22:54:45.950787Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.950818Z [INFO ] TRIAL 0: Fitness is 0.000000012603489
# 2024-06-10T22:54:45.951539Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.951570Z [INFO ] TRIAL 0: Fitness is 0.000000775290410
# 2024-06-10T22:54:45.952296Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.952326Z [INFO ] TRIAL 0: Fitness is 0.000000730151906
# 2024-06-10T22:54:45.953048Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.953077Z [INFO ] TRIAL 0: Fitness is 0.000000782733012
# 2024-06-10T22:54:45.953800Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.953830Z [INFO ] TRIAL 0: Fitness is 0.000000771338629
# 2024-06-10T22:54:45.954550Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.954579Z [INFO ] TRIAL 0: Fitness is 0.000000006215199
# 2024-06-10T22:54:45.955303Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.955332Z [INFO ] TRIAL 0: Fitness is 0.000000004921510
# 2024-06-10T22:54:45.956063Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.956092Z [INFO ] TRIAL 0: Fitness is 0.000208879567463
# 2024-06-10T22:54:45.956816Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.956846Z [INFO ] TRIAL 0: Fitness is 0.000186011213956
# 2024-06-10T22:54:45.957573Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.957603Z [INFO ] TRIAL 0: Fitness is 0.000001197279579
# 2024-06-10T22:54:45.958320Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.958350Z [INFO ] TRIAL 0: Fitness is 0.000001309757517
# 2024-06-10T22:54:45.959067Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.959101Z [INFO ] TRIAL 0: Fitness is 0.000000006760262
# 2024-06-10T22:54:45.959834Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.959863Z [INFO ] TRIAL 0: Fitness is 0.000000005528342
# 2024-06-10T22:54:45.960630Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.960660Z [INFO ] TRIAL 0: Fitness is 0.000240106870561
# 2024-06-10T22:54:45.961379Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.961409Z [INFO ] TRIAL 0: Fitness is 0.000223883805711
# 2024-06-10T22:54:45.962134Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.962164Z [INFO ] TRIAL 0: Fitness is 0.000001343255948
# 2024-06-10T22:54:45.962886Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.962915Z [INFO ] TRIAL 0: Fitness is 0.000001464433288
# 2024-06-10T22:54:45.963638Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.963667Z [INFO ] TRIAL 0: Fitness is 0.000026350076033
# 2024-06-10T22:54:45.964398Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.964428Z [INFO ] TRIAL 0: Fitness is 0.000030885584509
# 2024-06-10T22:54:45.965149Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.965179Z [INFO ] TRIAL 0: Fitness is 0.000001079601966
# 2024-06-10T22:54:45.965905Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.965934Z [INFO ] TRIAL 0: Fitness is 0.000000924366771
# 2024-06-10T22:54:45.966658Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.966687Z [INFO ] TRIAL 0: Fitness is 0.000000165245815
# 2024-06-10T22:54:45.967405Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.967434Z [INFO ] TRIAL 0: Fitness is 0.000000114714290
# 2024-06-10T22:54:45.968169Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.968199Z [INFO ] TRIAL 0: Fitness is 0.000000001315987
# 2024-06-10T22:54:45.968922Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.968951Z [INFO ] TRIAL 0: Fitness is 0.000000001656300
# 2024-06-10T22:54:45.969676Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.969706Z [INFO ] TRIAL 0: Fitness is 0.000001215480570
# 2024-06-10T22:54:45.970424Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.970454Z [INFO ] TRIAL 0: Fitness is 0.000001089013693
# 2024-06-10T22:54:45.971173Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.971203Z [INFO ] TRIAL 0: Fitness is 0.000000227340922
# 2024-06-10T22:54:45.971918Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.971948Z [INFO ] TRIAL 0: Fitness is 0.000000157098324
# 2024-06-10T22:54:45.972735Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.972765Z [INFO ] TRIAL 0: Fitness is 0.000000000773047
# 2024-06-10T22:54:45.973492Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.973522Z [INFO ] TRIAL 0: Fitness is 0.000000000614906
# 2024-06-10T22:54:45.974241Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.974271Z [INFO ] TRIAL 0: Fitness is 0.000021955537116
# 2024-06-10T22:54:45.974990Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.975019Z [INFO ] TRIAL 0: Fitness is 0.000018926270454
# 2024-06-10T22:54:45.975744Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.975774Z [INFO ] TRIAL 0: Fitness is 0.000000100747393
# 2024-06-10T22:54:45.976497Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.976527Z [INFO ] TRIAL 0: Fitness is 0.000000104742081
# 2024-06-10T22:54:45.977247Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.977276Z [INFO ] TRIAL 0: Fitness is 0.000000000918833
# 2024-06-10T22:54:45.977996Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.978026Z [INFO ] TRIAL 0: Fitness is 0.000000000580247
# 2024-06-10T22:54:45.978742Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.978773Z [INFO ] TRIAL 0: Fitness is 0.000026960709663
# 2024-06-10T22:54:45.979503Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.979533Z [INFO ] TRIAL 0: Fitness is 0.000018850376116
# 2024-06-10T22:54:45.980291Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.980321Z [INFO ] TRIAL 0: Fitness is 0.000000702974759
# 2024-06-10T22:54:45.981049Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.981079Z [INFO ] TRIAL 0: Fitness is 0.000000729577401
# 2024-06-10T22:54:45.981814Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.981844Z [INFO ] TRIAL 0: Fitness is 0.000027112688558
# 2024-06-10T22:54:45.982577Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.982607Z [INFO ] TRIAL 0: Fitness is 0.000033398775182
# 2024-06-10T22:54:45.983329Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.983357Z [INFO ] TRIAL 0: Fitness is 0.000001107524145
# 2024-06-10T22:54:45.984103Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.984133Z [INFO ] TRIAL 0: Fitness is 0.000000989221963
# 2024-06-10T22:54:45.984857Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.984887Z [INFO ] TRIAL 0: Fitness is 0.000000168686543
# 2024-06-10T22:54:45.985620Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.985649Z [INFO ] TRIAL 0: Fitness is 0.000000117020904
# 2024-06-10T22:54:45.986373Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.986403Z [INFO ] TRIAL 0: Fitness is 0.000000001351062
# 2024-06-10T22:54:45.987140Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.987169Z [INFO ] TRIAL 0: Fitness is 0.000000001780134
# 2024-06-10T22:54:45.987894Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.987923Z [INFO ] TRIAL 0: Fitness is 0.000001254709744
# 2024-06-10T22:54:45.988655Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.988685Z [INFO ] TRIAL 0: Fitness is 0.000001180801598
# 2024-06-10T22:54:45.989415Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.989445Z [INFO ] TRIAL 0: Fitness is 0.000000233511824
# 2024-06-10T22:54:45.990182Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.990211Z [INFO ] TRIAL 0: Fitness is 0.000000160946615
# 2024-06-10T22:54:45.990940Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.990970Z [INFO ] TRIAL 0: Fitness is 0.000000000793705
# 2024-06-10T22:54:45.991695Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.991724Z [INFO ] TRIAL 0: Fitness is 0.000000000659537
# 2024-06-10T22:54:45.992479Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.992508Z [INFO ] TRIAL 0: Fitness is 0.000022803197748
# 2024-06-10T22:54:45.993232Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.993261Z [INFO ] TRIAL 0: Fitness is 0.000020821645632
# 2024-06-10T22:54:45.993981Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.994011Z [INFO ] TRIAL 0: Fitness is 0.000000103302011
# 2024-06-10T22:54:45.994737Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.994766Z [INFO ] TRIAL 0: Fitness is 0.000000107281829
# 2024-06-10T22:54:45.995492Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.995521Z [INFO ] TRIAL 0: Fitness is 0.000000000837734
# 2024-06-10T22:54:45.996262Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.996292Z [INFO ] TRIAL 0: Fitness is 0.000000000530488
# 2024-06-10T22:54:45.997020Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.997049Z [INFO ] TRIAL 0: Fitness is 0.000023545859911
# 2024-06-10T22:54:45.997785Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.997814Z [INFO ] TRIAL 0: Fitness is 0.000016704727091
# 2024-06-10T22:54:45.998543Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.998573Z [INFO ] TRIAL 0: Fitness is 0.000000631314065
# 2024-06-10T22:54:45.999291Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:45.999320Z [INFO ] TRIAL 0: Fitness is 0.000000658416449
# 2024-06-10T22:54:46.000054Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.000085Z [INFO ] TRIAL 0: Fitness is 0.000000014388173
# 2024-06-10T22:54:46.000807Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.000836Z [INFO ] TRIAL 0: Fitness is 0.000000014030937
# 2024-06-10T22:54:46.001557Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.001587Z [INFO ] TRIAL 0: Fitness is 0.000000000846317
# 2024-06-10T22:54:46.002322Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.002351Z [INFO ] TRIAL 0: Fitness is 0.000000001115794
# 2024-06-10T22:54:46.003072Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.003102Z [INFO ] TRIAL 0: Fitness is 0.000000000851816
# 2024-06-10T22:54:46.003834Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.003863Z [INFO ] TRIAL 0: Fitness is 0.000000001160411
# 2024-06-10T22:54:46.004601Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.004630Z [INFO ] TRIAL 0: Fitness is 0.000000003625725
# 2024-06-10T22:54:46.005371Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.005400Z [INFO ] TRIAL 0: Fitness is 0.000000003526964
# 2024-06-10T22:54:46.006124Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.006153Z [INFO ] TRIAL 0: Fitness is 0.000000000398278
# 2024-06-10T22:54:46.006882Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.006912Z [INFO ] TRIAL 0: Fitness is 0.000000000436831
# 2024-06-10T22:54:46.007635Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.007664Z [INFO ] TRIAL 0: Fitness is 0.000000000401003
# 2024-06-10T22:54:46.008896Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.008927Z [INFO ] TRIAL 0: Fitness is 0.000000000454761
# 2024-06-10T22:54:46.009698Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.009730Z [INFO ] TRIAL 0: Fitness is 0.000000002703281
# 2024-06-10T22:54:46.010481Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.010510Z [INFO ] TRIAL 0: Fitness is 0.000000003391025
# 2024-06-10T22:54:46.011242Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.011272Z [INFO ] TRIAL 0: Fitness is 0.000000004741755
# 2024-06-10T22:54:46.012010Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.012040Z [INFO ] TRIAL 0: Fitness is 0.000000005154492
# 2024-06-10T22:54:46.012764Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.012794Z [INFO ] TRIAL 0: Fitness is 0.000000001226211
# 2024-06-10T22:54:46.013520Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.013550Z [INFO ] TRIAL 0: Fitness is 0.000000001011574
# 2024-06-10T22:54:46.014280Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.014309Z [INFO ] TRIAL 0: Fitness is 0.000000002908250
# 2024-06-10T22:54:46.015032Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.015062Z [INFO ] TRIAL 0: Fitness is 0.000000003760747
# 2024-06-10T22:54:46.015790Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.015820Z [INFO ] TRIAL 0: Fitness is 0.000000005083317
# 2024-06-10T22:54:46.016549Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.016578Z [INFO ] TRIAL 0: Fitness is 0.000000005675136
# 2024-06-10T22:54:46.017311Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.017340Z [INFO ] TRIAL 0: Fitness is 0.000000001333482
# 2024-06-10T22:54:46.018070Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.018099Z [INFO ] TRIAL 0: Fitness is 0.000000001097465
# 2024-06-10T22:54:46.018832Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.018862Z [INFO ] TRIAL 0: Fitness is 0.000099299786350
# 2024-06-10T22:54:46.019601Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.019631Z [INFO ] TRIAL 0: Fitness is 0.000094844151587
# 2024-06-10T22:54:46.020409Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.020439Z [INFO ] TRIAL 0: Fitness is 0.000005485260603
# 2024-06-10T22:54:46.021170Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.021199Z [INFO ] TRIAL 0: Fitness is 0.000006517441948
# 2024-06-10T22:54:46.021936Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.021967Z [INFO ] TRIAL 0: Fitness is 0.000005539168890
# 2024-06-10T22:54:46.022693Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.022723Z [INFO ] TRIAL 0: Fitness is 0.000006920210522
# 2024-06-10T22:54:46.023460Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.023490Z [INFO ] TRIAL 0: Fitness is 0.000000144471549
# 2024-06-10T22:54:46.024224Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.024253Z [INFO ] TRIAL 0: Fitness is 0.000000138559529
# 2024-06-10T22:54:46.024978Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.025007Z [INFO ] TRIAL 0: Fitness is 0.000004887431455
# 2024-06-10T22:54:46.025735Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.025764Z [INFO ] TRIAL 0: Fitness is 0.000004225706279
# 2024-06-10T22:54:46.026490Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.026519Z [INFO ] TRIAL 0: Fitness is 0.000004953511092
# 2024-06-10T22:54:46.027249Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.027279Z [INFO ] TRIAL 0: Fitness is 0.000004554288332
# 2024-06-10T22:54:46.028018Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.028048Z [INFO ] TRIAL 0: Fitness is 0.000000110439461
# 2024-06-10T22:54:46.028784Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.028814Z [INFO ] TRIAL 0: Fitness is 0.000000134338164
# 2024-06-10T22:54:46.029542Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.029571Z [INFO ] TRIAL 0: Fitness is 0.000066219087617
# 2024-06-10T22:54:46.030288Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.030318Z [INFO ] TRIAL 0: Fitness is 0.000056602001179
# 2024-06-10T22:54:46.031046Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.031075Z [INFO ] TRIAL 0: Fitness is 0.000015076521018
# 2024-06-10T22:54:46.031804Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.031833Z [INFO ] TRIAL 0: Fitness is 0.000010567283196
# 2024-06-10T22:54:46.032559Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.032589Z [INFO ] TRIAL 0: Fitness is 0.000000123246795
# 2024-06-10T22:54:46.033308Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.033337Z [INFO ] TRIAL 0: Fitness is 0.000000157273529
# 2024-06-10T22:54:46.034067Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.034096Z [INFO ] TRIAL 0: Fitness is 0.000078130400032
# 2024-06-10T22:54:46.034820Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.034849Z [INFO ] TRIAL 0: Fitness is 0.000070192907999
# 2024-06-10T22:54:46.035574Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.035604Z [INFO ] TRIAL 0: Fitness is 0.000017868213472
# 2024-06-10T22:54:46.036336Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.036366Z [INFO ] TRIAL 0: Fitness is 0.000012266866867
# 2024-06-10T22:54:46.037087Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.037117Z [INFO ] TRIAL 0: Fitness is 0.000016449864027
# 2024-06-10T22:54:46.037850Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.037879Z [INFO ] TRIAL 0: Fitness is 0.000015868499601
# 2024-06-10T22:54:46.038604Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.038633Z [INFO ] TRIAL 0: Fitness is 0.000002003708905
# 2024-06-10T22:54:46.039355Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.039385Z [INFO ] TRIAL 0: Fitness is 0.000002061951648
# 2024-06-10T22:54:46.040169Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.040199Z [INFO ] TRIAL 0: Fitness is 0.000002019132595
# 2024-06-10T22:54:46.040921Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.040951Z [INFO ] TRIAL 0: Fitness is 0.000002156725942
# 2024-06-10T22:54:46.041684Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.041714Z [INFO ] TRIAL 0: Fitness is 0.000000096938531
# 2024-06-10T22:54:46.042449Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.042479Z [INFO ] TRIAL 0: Fitness is 0.000000094167975
# ...
# 2024-06-10T22:54:46.867203Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.867233Z [INFO ] TRIAL 0: Fitness is 0.000004422452857
# 2024-06-10T22:54:46.867986Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.868023Z [INFO ] TRIAL 0: Fitness is 0.000001736436853
# 2024-06-10T22:54:46.868758Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.868789Z [INFO ] TRIAL 0: Fitness is 0.000000125628962
# 2024-06-10T22:54:46.869520Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.869550Z [INFO ] TRIAL 0: Fitness is 0.000000159967327
# 2024-06-10T22:54:46.870270Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.870300Z [INFO ] TRIAL 0: Fitness is 0.000000042548836
# 2024-06-10T22:54:46.871032Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.871063Z [INFO ] TRIAL 0: Fitness is 0.000000008317908
# 2024-06-10T22:54:46.871791Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.871821Z [INFO ] TRIAL 0: Fitness is 0.000000234454390
# 2024-06-10T22:54:46.872559Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.872590Z [INFO ] TRIAL 0: Fitness is 0.000013013686159
# 2024-06-10T22:54:46.873317Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.873347Z [INFO ] TRIAL 0: Fitness is 0.002005155904615
# 2024-06-10T22:54:46.874071Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.874102Z [INFO ] TRIAL 0: Fitness is 0.000617844700619
# 2024-06-10T22:54:46.874824Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.874853Z [INFO ] TRIAL 0: Fitness is 0.000067991659449
# 2024-06-10T22:54:46.875571Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.875600Z [INFO ] TRIAL 0: Fitness is 0.000000011656430
# 2024-06-10T22:54:46.876359Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.876389Z [INFO ] TRIAL 0: Fitness is 0.000000010915570
# 2024-06-10T22:54:46.877121Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.877152Z [INFO ] TRIAL 0: Fitness is 0.000116081834695
# 2024-06-10T22:54:46.877879Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.877910Z [INFO ] TRIAL 0: Fitness is 0.000734865228994
# 2024-06-10T22:54:46.878640Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.878670Z [INFO ] TRIAL 0: Fitness is 0.000003475838388
# 2024-06-10T22:54:46.879387Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.879418Z [INFO ] TRIAL 0: Fitness is 0.000148624824742
# 2024-06-10T22:54:46.880164Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.880195Z [INFO ] TRIAL 0: Fitness is 0.000000003674263
# 2024-06-10T22:54:46.880928Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.880958Z [INFO ] TRIAL 0: Fitness is 0.000000003313142
# 2024-06-10T22:54:46.881684Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.881714Z [INFO ] TRIAL 0: Fitness is 0.000224160179492
# 2024-06-10T22:54:46.882444Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.882474Z [INFO ] TRIAL 0: Fitness is 0.000009693043962
# 2024-06-10T22:54:46.883205Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.883235Z [INFO ] TRIAL 0: Fitness is 0.000005145141755
# 2024-06-10T22:54:46.883961Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.883991Z [INFO ] TRIAL 0: Fitness is 0.002354565327522
# 2024-06-10T22:54:46.884734Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.884764Z [INFO ] TRIAL 0: Fitness is 0.000000052605606
# 2024-06-10T22:54:46.885498Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.885529Z [INFO ] TRIAL 0: Fitness is 0.000000179155073
# 2024-06-10T22:54:46.886258Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.886288Z [INFO ] TRIAL 0: Fitness is 0.000000281794531
# 2024-06-10T22:54:46.887012Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.887042Z [INFO ] TRIAL 0: Fitness is 0.000000008539465
# 2024-06-10T22:54:46.887772Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.887802Z [INFO ] TRIAL 0: Fitness is 0.000000058170563
# 2024-06-10T22:54:46.888533Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.888563Z [INFO ] TRIAL 0: Fitness is 0.000000016608101
# 2024-06-10T22:54:46.889288Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.889318Z [INFO ] TRIAL 0: Fitness is 0.000000021904391
# 2024-06-10T22:54:46.890049Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.890080Z [INFO ] TRIAL 0: Fitness is 0.000000117261779
# 2024-06-10T22:54:46.890802Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.890833Z [INFO ] TRIAL 0: Fitness is 0.000038755904421
# 2024-06-10T22:54:46.891559Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.891589Z [INFO ] TRIAL 0: Fitness is 0.001067554898588
# 2024-06-10T22:54:46.892345Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.892375Z [INFO ] TRIAL 0: Fitness is 0.000205508780844
# 2024-06-10T22:54:46.893103Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.893133Z [INFO ] TRIAL 0: Fitness is 0.000021496438148
# 2024-06-10T22:54:46.893870Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.893900Z [INFO ] TRIAL 0: Fitness is 0.000000004948019
# 2024-06-10T22:54:46.894618Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.894648Z [INFO ] TRIAL 0: Fitness is 0.000000004415426
# 2024-06-10T22:54:46.895379Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.895408Z [INFO ] TRIAL 0: Fitness is 0.000052228982393
# 2024-06-10T22:54:46.896156Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.896186Z [INFO ] TRIAL 0: Fitness is 0.000318297889892
# 2024-06-10T22:54:46.896913Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.896944Z [INFO ] TRIAL 0: Fitness is 0.000017356101158
# 2024-06-10T22:54:46.897671Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.897701Z [INFO ] TRIAL 0: Fitness is 0.000058403951775
# 2024-06-10T22:54:46.898433Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.898463Z [INFO ] TRIAL 0: Fitness is 0.000000001227624
# 2024-06-10T22:54:46.899191Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.899221Z [INFO ] TRIAL 0: Fitness is 0.000000001126041
# 2024-06-10T22:54:46.899948Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.899978Z [INFO ] TRIAL 0: Fitness is 0.000126337005037
# 2024-06-10T22:54:46.900710Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.900740Z [INFO ] TRIAL 0: Fitness is 0.000028353789898
# 2024-06-10T22:54:46.901469Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.901499Z [INFO ] TRIAL 0: Fitness is 0.000026798254341
# 2024-06-10T22:54:46.902227Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.902257Z [INFO ] TRIAL 0: Fitness is 0.000899171160069
# 2024-06-10T22:54:46.902984Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.903014Z [INFO ] TRIAL 0: Fitness is 0.000000020268390
# 2024-06-10T22:54:46.903746Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.903776Z [INFO ] TRIAL 0: Fitness is 0.000000065227367
# 2024-06-10T22:54:46.904511Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.904541Z [INFO ] TRIAL 0: Fitness is 0.000000146112178
# 2024-06-10T22:54:46.905265Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.905295Z [INFO ] TRIAL 0: Fitness is 0.000000023366404
# 2024-06-10T22:54:46.906016Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.906046Z [INFO ] TRIAL 0: Fitness is 0.000000007316886
# 2024-06-10T22:54:46.906778Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.906808Z [INFO ] TRIAL 0: Fitness is 0.000000206376805
# 2024-06-10T22:54:46.907541Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.907572Z [INFO ] TRIAL 0: Fitness is 0.000000052832839
# 2024-06-10T22:54:46.908343Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.908373Z [INFO ] TRIAL 0: Fitness is 0.000000279854308
# 2024-06-10T22:54:46.909111Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.909142Z [INFO ] TRIAL 0: Fitness is 0.000730537185970
# 2024-06-10T22:54:46.909880Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.909910Z [INFO ] TRIAL 0: Fitness is 0.000117615764681
# 2024-06-10T22:54:46.910643Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.910673Z [INFO ] TRIAL 0: Fitness is 0.000014283191416
# 2024-06-10T22:54:46.911403Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.911433Z [INFO ] TRIAL 0: Fitness is 0.000600460693896
# 2024-06-10T22:54:46.912161Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.912192Z [INFO ] TRIAL 0: Fitness is 0.000000012149902
# 2024-06-10T22:54:46.912921Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.912952Z [INFO ] TRIAL 0: Fitness is 0.000000010719263
# 2024-06-10T22:54:46.913680Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.913710Z [INFO ] TRIAL 0: Fitness is 0.000885553748521
# 2024-06-10T22:54:46.914437Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.914467Z [INFO ] TRIAL 0: Fitness is 0.000033094039943
# 2024-06-10T22:54:46.915276Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.915309Z [INFO ] TRIAL 0: Fitness is 0.000227399130045
# 2024-06-10T22:54:46.916069Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.916100Z [INFO ] TRIAL 0: Fitness is 0.000697596549311
# 2024-06-10T22:54:46.916829Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.916859Z [INFO ] TRIAL 0: Fitness is 0.000000009403834
# 2024-06-10T22:54:46.917581Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.917611Z [INFO ] TRIAL 0: Fitness is 0.000000008883181
# 2024-06-10T22:54:46.918345Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.918375Z [INFO ] TRIAL 0: Fitness is 0.001073152636829
# 2024-06-10T22:54:46.919108Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.919138Z [INFO ] TRIAL 0: Fitness is 0.000259975816717
# 2024-06-10T22:54:46.919867Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.919897Z [INFO ] TRIAL 0: Fitness is 0.000856339233583
# 2024-06-10T22:54:46.920639Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.920670Z [INFO ] TRIAL 0: Fitness is 0.000060398242348
# 2024-06-10T22:54:46.921395Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.921425Z [INFO ] TRIAL 0: Fitness is 0.000000248252858
# 2024-06-10T22:54:46.922154Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.922185Z [INFO ] TRIAL 0: Fitness is 0.000000007620666
# 2024-06-10T22:54:46.922908Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.922938Z [INFO ] TRIAL 0: Fitness is 0.000000356552130
# 2024-06-10T22:54:46.923670Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.923699Z [INFO ] TRIAL 0: Fitness is 0.000000056847822
# 2024-06-10T22:54:46.924458Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.924488Z [INFO ] TRIAL 0: Fitness is 0.000000046856159
# 2024-06-10T22:54:46.925217Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.925247Z [INFO ] TRIAL 0: Fitness is 0.000005331902856
# 2024-06-10T22:54:46.925982Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.926011Z [INFO ] TRIAL 0: Fitness is 0.000000300289244
# 2024-06-10T22:54:46.926748Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.926778Z [INFO ] TRIAL 0: Fitness is 0.000006600485537
# 2024-06-10T22:54:46.927509Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.927538Z [INFO ] TRIAL 0: Fitness is 0.000002001499179
# 2024-06-10T22:54:46.928275Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.928305Z [INFO ] TRIAL 0: Fitness is 0.000000330045927
# 2024-06-10T22:54:46.929032Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.929062Z [INFO ] TRIAL 0: Fitness is 0.000013950968086
# 2024-06-10T22:54:46.929835Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.929867Z [INFO ] TRIAL 0: Fitness is 0.006546688558551
# 2024-06-10T22:54:46.930651Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.930681Z [INFO ] TRIAL 0: Fitness is 0.000000102064075
# 2024-06-10T22:54:46.931418Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.931448Z [INFO ] TRIAL 0: Fitness is 0.000000368058378
# 2024-06-10T22:54:46.932206Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.932236Z [INFO ] TRIAL 0: Fitness is 0.000000590204268
# 2024-06-10T22:54:46.932970Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.933000Z [INFO ] TRIAL 0: Fitness is 0.000000017067986
# 2024-06-10T22:54:46.933731Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.933761Z [INFO ] TRIAL 0: Fitness is 0.000247439396123
# 2024-06-10T22:54:46.934496Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.934525Z [INFO ] TRIAL 0: Fitness is 0.007780546617510
# 2024-06-10T22:54:46.935239Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.935269Z [INFO ] TRIAL 0: Fitness is 0.000000093504411
# 2024-06-10T22:54:46.936005Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.936035Z [INFO ] TRIAL 0: Fitness is 0.000000330217968
# 2024-06-10T22:54:46.936764Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.936794Z [INFO ] TRIAL 0: Fitness is 0.000000724018708
# 2024-06-10T22:54:46.937520Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.937550Z [INFO ] TRIAL 0: Fitness is 0.000000131941113
# 2024-06-10T22:54:46.938287Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.938317Z [INFO ] TRIAL 0: Fitness is 0.000585273950923
# 2024-06-10T22:54:46.939038Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.939067Z [INFO ] TRIAL 0: Fitness is 0.000043507291685
# 2024-06-10T22:54:46.939788Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.939818Z [INFO ] TRIAL 0: Fitness is 0.000000151622334
# 2024-06-10T22:54:46.940566Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.940596Z [INFO ] TRIAL 0: Fitness is 0.000000004929171
# 2024-06-10T22:54:46.941324Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.941355Z [INFO ] TRIAL 0: Fitness is 0.000000218078454
# 2024-06-10T22:54:46.942080Z [INFO ] Loaded genome  containing 1 genes - trial set to 0
# 2024-06-10T22:54:46.942110Z [INFO ] TRIAL 0: Fitness is 0.000000035944654

# %% [markdown]
# ### ignore the rest

# %%
"""
# Edited from xmlparse.py
def loadRef(ref_char, ref_dir):
    stroke_list = []
    frac_dists = []
    ref_path = f'{ref_dir}/{ref_char}.han'
    ref_xml = open(ref_path, "r").read()
    root = xmltodict.parse(ref_xml)
    bounds = root["hanDefinition"]["bounds"]
    x_min, y_min, x_max, y_max = (float(bounds["@left"]), float(bounds["@bottom"]), float(bounds["@right"]), float(bounds["@top"]))
    scale = (int(x_max-x_min), int(y_max-y_min))
    strokes = root["hanDefinition"]["strokes"]["stroke"]
    if isinstance(strokes, dict):
        strokes = [strokes]
    for stroke in strokes:
        points = stroke["points"]["forward"]
        point_arr = []
        frac_arr = []
        for point in points["pointDistance"]:
            point_arr.append((float(point["@x"])-x_min,
                               float(point["@y"])-y_min))
            frac_arr.append(float(point["@fractionalDistance"]))
        stroke_list.append(np.array(point_arr))
        frac_dists.append(np.array(frac_arr))
    return stroke_list, frac_dists, scale

# Obtaining scores through heuristic algorithm
def heuristicScores(algo, ref_char, ref_data, char_data):
    heuristic_alignments = []
    heuristic_scores = []
    ref_geometry, ref_progress_percentage, output_size = ref_data
    g_data, _, base_data, stroke_sets, _, _ = char_data
    for (geometry_length, bases, stroke_set) in zip(g_data, base_data, stroke_sets):
        geometry, progress_percentage = geometry_length
        heuristic_alignment = np.array(algo(geometry, ref_geometry, progress_percentage, ref_progress_percentage))+1
        heuristic_alignments.append(heuristic_alignment)
        heuristic_xml = minXml(ref_char, bases, stroke_set, heuristic_alignment)
        heuristic_score = getXmlScore(heuristic_xml)
        heuristic_scores.append(heuristic_score)
    return heuristic_scores, heuristic_alignments
"""
# Out:
# '\n# Edited from xmlparse.py\ndef loadRef(ref_char, ref_dir):\n    stroke_list = []\n    frac_dists = []\n    ref_path = f\'{ref_dir}/{ref_char}.han\'\n    ref_xml = open(ref_path, "r").read()\n    root = xmltodict.parse(ref_xml)\n    bounds = root["hanDefinition"]["bounds"]\n    x_min, y_min, x_max, y_max = (float(bounds["@left"]), float(bounds["@bottom"]), float(bounds["@right"]), float(bounds["@top"]))\n    scale = (int(x_max-x_min), int(y_max-y_min))\n    strokes = root["hanDefinition"]["strokes"]["stroke"]\n    if isinstance(strokes, dict):\n        strokes = [strokes]\n    for stroke in strokes:\n        points = stroke["points"]["forward"]\n        point_arr = []\n        frac_arr = []\n        for point in points["pointDistance"]:\n            point_arr.append((float(point["@x"])-x_min,\n                               float(point["@y"])-y_min))\n            frac_arr.append(float(point["@fractionalDistance"]))\n        stroke_list.append(np.array(point_arr))\n        frac_dists.append(np.array(frac_arr))\n    return stroke_list, frac_dists, scale\n\n# Obtaining scores through heuristic algorithm\ndef heuristicScores(algo, ref_char, ref_data, char_data):\n    heuristic_alignments = []\n    heuristic_scores = []\n    ref_geometry, ref_progress_percentage, output_size = ref_data\n    g_data, _, base_data, stroke_sets, _, _ = char_data\n    for (geometry_length, bases, stroke_set) in zip(g_data, base_data, stroke_sets):\n        geometry, progress_percentage = geometry_length\n        heuristic_alignment = np.array(algo(geometry, ref_geometry, progress_percentage, ref_progress_percentage))+1\n        heuristic_alignments.append(heuristic_alignment)\n        heuristic_xml = minXml(ref_char, bases, stroke_set, heuristic_alignment)\n        heuristic_score = getXmlScore(heuristic_xml)\n        heuristic_scores.append(heuristic_score)\n    return heuristic_scores, heuristic_alignments\n'

# %%
"""
def getArchetypes(ref_dir):
    ref_chars = []
    ref_datas = []
    for _, _, f_names in os.walk(ref_dir):
        ref_chars.extend(f.split(".")[0] for f in f_names)
        ref_datas.extend(loadRef(f.split(".")[0], ref_dir) for f in f_names)
    ref_chars = list(filter(None, ref_chars))
    ref_datas = list(filter(None, ref_datas))
    return ref_chars, ref_datas

def writeData(archetypes, ref_dir, data_dir):
    all_scores = []
    ref_chars, ref_datas = archetypes
    for (ref_char, ref_data) in zip(ref_chars, ref_datas):
        char_data = loadGeometryBases(data_dir, ref_data[2])
        for stroke in char_data[0][0]:
            if len(ref_data[0]) != len(stroke):
                break
        else:
            heuristic_scores, _ = heuristicScores(alignStrokes, ref_char, ref_data, char_data)
            all_scores.append(heuristic_scores)
    np.array(all_scores)

#def readData():
"""
# Out:
# '\ndef getArchetypes(ref_dir):\n    ref_chars = []\n    ref_datas = []\n    for _, _, f_names in os.walk(ref_dir):\n        ref_chars.extend(f.split(".")[0] for f in f_names)\n        ref_datas.extend(loadRef(f.split(".")[0], ref_dir) for f in f_names)\n    ref_chars = list(filter(None, ref_chars))\n    ref_datas = list(filter(None, ref_datas))\n    return ref_chars, ref_datas\n\ndef writeData(archetypes, ref_dir, data_dir):\n    all_scores = []\n    ref_chars, ref_datas = archetypes\n    for (ref_char, ref_data) in zip(ref_chars, ref_datas):\n        char_data = loadGeometryBases(data_dir, ref_data[2])\n        for stroke in char_data[0][0]:\n            if len(ref_data[0]) != len(stroke):\n                break\n        else:\n            heuristic_scores, _ = heuristicScores(alignStrokes, ref_char, ref_data, char_data)\n            all_scores.append(heuristic_scores)\n    np.array(all_scores)\n\n#def readData():\n'

# %%
"""
ref_dir = f'{str(Path.home())}/Stylus_Scoring_Generalization/NewRef' # archetype directory
data_dir = f'{str(Path.home())}/Stylus_Scoring_Generalization/NewGenes' # gene directory

archetypes = getArchetypes(ref_dir)
writeData(archetypes, ref_dir, data_dir)
"""
# Out:
# "\nref_dir = f'{str(Path.home())}/Stylus_Scoring_Generalization/NewRef' # archetype directory\ndata_dir = f'{str(Path.home())}/Stylus_Scoring_Generalization/NewGenes' # gene directory\n\narchetypes = getArchetypes(ref_dir)\nwriteData(archetypes, ref_dir, data_dir)\n"
